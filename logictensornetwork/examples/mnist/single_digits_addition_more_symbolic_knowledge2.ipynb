# %% [markdown]
# # MNIST Digit Addition Problem with More Symbolic Knowledge
#
# Consider a task where one needs to learn a classifier $\mathtt{addition(X,Y,N)}$ where $\mathtt{X}$ and $\mathtt{Y}$ are images of digits (the MNIST data set will be used), and $\mathtt{N}$ is a natural number corresponding to the sum of these digits, if both of them are even, otherwise -1, that we' ll call special_sum from now on. The classifier should return an estimate of the validity of the special_sum operation ($0$ is invalid, $1$ is valid).

# %%
import tensorflow as tf
import ltn
import baselines, data, commons_with_debug as commons
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data
#
# Dataset of images for the digits X and Y, and their label Z s.t. X+Y=Z.

# %%
def op_with_even_check(args):
    x, y = args[0], args[1]
    if x % 2 == 1 and y % 2 == 1:
        return 1
    else:
        return x+y

ds_train, ds_test = data.get_mnist_op_dataset(
    count_train=3000,
    count_test=1000,
    buffer_size=3000,
    batch_size=16,
    n_operands=2,
    op=op_with_even_check
)


# Visualize one example
x, y, z = next(ds_train.as_numpy_iterator())
plt.subplot(121)
plt.imshow(x[0][:,:,0])
plt.subplot(122)
plt.imshow(y[0][:,:,0])
print("Result label is %i" % z[0])
# Out:
# Result label is 1

# %% [markdown]
# ## LTN

# %%
logits_model = baselines.SingleDigit(inputs_as_a_list=True)
@tf.function
def digit_softmax_wrapper(x):
    return tf.nn.softmax(logits_model(x))

class SoftmaxDigitModel(tf.keras.Model):
    def __init__(self, base_model):
        super().__init__()
        self.base_model = base_model

    def call(self, x):
        logits = self.base_model(x)
        return tf.nn.softmax(logits)

# Create model with softmax built-in
softmax_model = SoftmaxDigitModel(logits_model)

Digit = ltn.Predicate.Lambda(lambda inputs: tf.gather(
    softmax_model([inputs[0]]), 
    indices=tf.cast(inputs[1], tf.int32), 
    axis=1,
    batch_dims=1
))

d1 = ltn.Variable("digits1", range(10))
d2 = ltn.Variable("digits2", range(10))

Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(),semantics="exists")

formula_aggregator = ltn.Wrapper_Formula_Aggregator(ltn.fuzzy_ops.Aggreg_pMeanError())

# %% [markdown]
# Notice the use of `Diag`: when grounding $x$,$y$,$n$ with three sequences of values, the $i$-th examples of each variable are matching.
# That is, `(images_x[i],images_y[i],labels[i])` is a tuple from our dataset of valid additions.
# Using the diagonal quantification, LTN aggregates pairs of images and their corresponding result, rather than any combination of images and results.
#
# Notice also the guarded quantification: by quantifying only on the "intermediate labels" (not given during training) that could add up to the result label (given during training), we incorporate symbolic information into the system.

# %%
# mask
add = ltn.Function.Lambda(lambda inputs: inputs[0]+inputs[1])
equals = ltn.Predicate.Lambda(lambda inputs: inputs[0] == inputs[1])
is_even = ltn.Predicate.Lambda(lambda inputs: tf.equal(inputs[0] % 2, 0))
is_odd = ltn.Predicate.Lambda(lambda inputs: tf.equal(inputs[0] % 2, 1))
minus_one = tf.constant(1, dtype=tf.int32)
### Axioms
@tf.function
def axioms(images_x, images_y, labels_z, p_schedule=tf.constant(2.)):
    images_x = ltn.Variable("x", images_x)
    images_y = ltn.Variable("y", images_y)
    labels_z = ltn.Variable("z", labels_z)
    minus_one = ltn.Constant([1], trainable=False)

    axiomOne = Forall(
            ltn.diag(images_x,images_y,labels_z),
            Exists(
                (d1,d2),
                And(Digit([images_x,d1]),Digit([images_y,d2])),
                mask=equals([add([d1,d2]), labels_z]) and (is_even([d1]) or is_even([d2])),
                p=p_schedule
            ),
            p=2
        )
    axiomTwo = Forall(
            ltn.diag(images_x,images_y,labels_z),
            Exists(
                (d1,d2),
                And(Digit([images_x,d1]),Digit([images_y,d2])),
                mask=equals([minus_one, labels_z]) and (is_odd([d1]) and is_odd([d2])),
                p=p_schedule
            ),
            p=2
        )
    axioms = [axiomOne, axiomTwo]
    sat_level = formula_aggregator(axioms).tensor
    return sat_level

images_x, images_y, labels_z = next(ds_train.as_numpy_iterator())
axioms(images_x, images_y, labels_z)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.010293722152709961>

# %% [markdown]
# Optimizer, training steps and metrics

# %%
optimizer = tf.keras.optimizers.Adam(0.001)
metrics_dict = {
    'train_loss': tf.keras.metrics.Mean(name="train_loss"),
    'train_accuracy': tf.keras.metrics.Mean(name="train_accuracy"),
    'test_loss': tf.keras.metrics.Mean(name="test_loss"),
    'test_accuracy': tf.keras.metrics.Mean(name="test_accuracy")    
}
def op_with_even_check_tensor(args):
    x, y = args
    x_odd = tf.equal(x % 2, 1)
    y_odd = tf.equal(y % 2, 1)
    minus_one = tf.constant(1, dtype=x.dtype)
    both_odd = tf.logical_and(x_odd, y_odd)
    result = tf.where(both_odd, minus_one, x+y)
    return result

@tf.function
def train_step(images_x, images_y, labels_z, **parameters):
    # loss
    with tf.GradientTape() as tape:
        loss = 1.- axioms(images_x, images_y, labels_z, **parameters)
    gradients = tape.gradient(loss, logits_model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, logits_model.trainable_variables))
    metrics_dict['train_loss'](loss)
    # accuracy
    predictions_x = tf.argmax(logits_model([images_x]),axis=-1)
    predictions_y = tf.argmax(logits_model([images_y]),axis=-1)
    predictions_z = op_with_even_check_tensor((predictions_x, predictions_y))
    match = tf.equal(predictions_z,tf.cast(labels_z,predictions_z.dtype))
    metrics_dict['train_accuracy'](tf.reduce_mean(tf.cast(match,tf.float32)))
    
@tf.function
def test_step(images_x, images_y, labels_z, **parameters):
    # loss
    loss = 1.- axioms(images_x, images_y, labels_z, **parameters)
    metrics_dict['test_loss'](loss)
    # accuracy
    predictions_x = tf.argmax(logits_model([images_x]),axis=-1)
    predictions_y = tf.argmax(logits_model([images_y]),axis=-1)
    predictions_z =  op_with_even_check_tensor((predictions_x, predictions_y))
    match = tf.equal(predictions_z,tf.cast(labels_z,predictions_z.dtype))
    metrics_dict['test_accuracy'](tf.reduce_mean(tf.cast(match,tf.float32)))
    return predictions_x, predictions_y, predictions_z, labels_z, images_x, images_y

# %% [markdown]
# Training

# %%
from collections import defaultdict

scheduled_parameters = defaultdict(lambda: {})
for epoch in range(0,4):
    scheduled_parameters[epoch] = {"p_schedule":tf.constant(1.)}
for epoch in range(4,8):
    scheduled_parameters[epoch] = {"p_schedule":tf.constant(2.)}
for epoch in range(8,12):
    scheduled_parameters[epoch] = {"p_schedule":tf.constant(4.)}
for epoch in range(12,20):
    scheduled_parameters[epoch] = {"p_schedule":tf.constant(6.)}
for epoch in range(20,30):
    scheduled_parameters[epoch] = {"p_schedule":tf.constant(8.)}

# %%
history = commons.train(
    epochs=30,
    metrics_dict=metrics_dict,
    ds_train=ds_train,
    ds_test=ds_test,
    train_step=train_step,
    test_step=test_step,
    scheduled_parameters=scheduled_parameters
)
# Out:
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 6, Predicted: 12
#  pred_x: 0, pred_y : 9, Real: 2, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 16, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 6, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 3, pred_y : 6, Real: 15, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 6, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 0, Real: 5, Predicted: 6
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 8, pred_y : 6, Real: 1, Predicted: 14
#  pred_x: 6, pred_y : 9, Real: 10, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 0, pred_y : 0, Real: 9, Predicted: 0
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 0, pred_y : 9, Real: 8, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 0, pred_y : 9, Real: 1, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 6, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 5, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 8, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 12, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 2, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 17, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 3, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 0, Real: 5, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 3, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 0, pred_y : 6, Real: 10, Predicted: 6
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 15, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 11, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 12, Predicted: 1
#  pred_x: 6, pred_y : 3, Real: 7, Predicted: 9
#  pred_x: 3, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 12, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 0, Real: 2, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 14, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 9, pred_y : 0, Real: 6, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 0, Real: 1, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 10, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 8, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 12, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 12, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 6, pred_y : 0, Real: 9, Predicted: 6
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 8, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 6, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 5, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 3, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 8, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 11, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 10, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 11, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 3, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 13, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 3, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 0, pred_y : 6, Real: 9, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 8, Predicted: 15
#  pred_x: 0, pred_y : 0, Real: 8, Predicted: 0
#  pred_x: 9, pred_y : 6, Real: 2, Predicted: 15
#  pred_x: 6, pred_y : 0, Real: 3, Predicted: 6
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 3, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 6, pred_y : 8, Real: 1, Predicted: 14
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 10, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 17, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 11, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 0, pred_y : 6, Real: 9, Predicted: 6
#  pred_x: 8, pred_y : 6, Real: 1, Predicted: 14
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 0, Real: 11, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 2, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 16, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 8, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 17, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 17, Predicted: 15
#  pred_x: 0, pred_y : 6, Real: 1, Predicted: 6
#  pred_x: 9, pred_y : 6, Real: 10, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 0, pred_y : 0, Real: 11, Predicted: 0
#  pred_x: 0, pred_y : 9, Real: 8, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 2, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 12, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 11, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 11, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 0, Predicted: 1
#  pred_x: 9, pred_y : 0, Real: 2, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 10, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 11, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 0, pred_y : 6, Real: 1, Predicted: 6
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 10, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 0, pred_y : 9, Real: 11, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 11, Predicted: 15
#  pred_x: 0, pred_y : 9, Real: 7, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 0, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 0, Real: 1, Predicted: 6
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 12, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 10, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 2, Predicted: 1
#  pred_x: 0, pred_y : 9, Real: 6, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 14, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 12, Predicted: 15
#  pred_x: 9, pred_y : 0, Real: 7, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 6, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 16, Predicted: 12
#  pred_x: 0, pred_y : 6, Real: 4, Predicted: 6
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 0, Real: 4, Predicted: 6
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 3, Real: 6, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 10, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 2, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 5, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 14, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 3, pred_y : 6, Real: 13, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 17, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 3, Real: 12, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 10, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 12, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 16, Predicted: 15
#  pred_x: 0, pred_y : 6, Real: 11, Predicted: 6
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 17, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 10, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 14, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 6, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 5, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 4, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 6, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 10, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 12, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 11, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 6, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 0, Real: 2, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 12, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 3, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 4, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 6, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 11, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 2, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 10, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 17, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 12, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 17, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 3, pred_y : 6, Real: 1, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 5, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 0, Real: 6, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 5, Predicted: 1
#  pred_x: 9, pred_y : 0, Real: 4, Predicted: 9
#  pred_x: 0, pred_y : 6, Real: 1, Predicted: 6
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 17, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 15, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 6, pred_y : 0, Real: 9, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 9, pred_y : 0, Real: 7, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 5, Predicted: 1
#  pred_x: 0, pred_y : 6, Real: 10, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 17, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 12, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 6, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 11, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 15, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 12, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 2, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 0, pred_y : 6, Real: 8, Predicted: 6
#  pred_x: 9, pred_y : 3, Real: 1, Predicted: 1
#  pred_x: 3, pred_y : 6, Real: 1, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 3, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 16, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 10, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 17, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 4, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 8, pred_y : 9, Real: 11, Predicted: 17
#  pred_x: 6, pred_y : 0, Real: 8, Predicted: 6
#  pred_x: 9, pred_y : 0, Real: 7, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 12, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 3, Real: 1, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 0, pred_y : 6, Real: 9, Predicted: 6
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 0, pred_y : 6, Real: 9, Predicted: 6
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 15, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 0, pred_y : 6, Real: 11, Predicted: 6
#  pred_x: 6, pred_y : 9, Real: 15, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 17, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 0, pred_y : 9, Real: 1, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 14, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 10, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 14, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 14, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 17, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 15, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 0, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 12, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 10, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 0, pred_y : 6, Real: 1, Predicted: 6
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 0, pred_y : 6, Real: 12, Predicted: 6
#  pred_x: 0, pred_y : 6, Real: 1, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 17, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 15, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 3, Real: 17, Predicted: 9
#  pred_x: 6, pred_y : 0, Real: 9, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 8, pred_y : 6, Real: 9, Predicted: 14
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 15, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 3, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 0, Real: 10, Predicted: 6
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 14, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 13, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 3, pred_y : 6, Real: 15, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 8, Predicted: 15
#  pred_x: 9, pred_y : 3, Real: 9, Predicted: 1
#  pred_x: 6, pred_y : 3, Real: 1, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 11, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 0, pred_y : 6, Real: 8, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 11, Predicted: 15
#  pred_x: 6, pred_y : 0, Real: 9, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 0, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 8, pred_y : 6, Real: 11, Predicted: 14
#  pred_x: 9, pred_y : 9, Real: 15, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 0, Real: 9, Predicted: 6
#  pred_x: 9, pred_y : 9, Real: 0, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 8, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 3, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 8, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 14, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 17, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 16, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 12, Predicted: 1
#  pred_x: 3, pred_y : 6, Real: 11, Predicted: 9
#  pred_x: 6, pred_y : 3, Real: 5, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 15, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 12, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 12, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 2, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 12, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 10, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 4, Predicted: 15
#  pred_x: 0, pred_y : 6, Real: 12, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 6, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 6, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 6, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 3, pred_y : 9, Real: 12, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 0, Real: 1, Predicted: 6
#  pred_x: 9, pred_y : 9, Real: 6, Predicted: 1
#  pred_x: 0, pred_y : 9, Real: 8, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 3, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 6, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 0, pred_y : 9, Real: 6, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 12, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 0, Real: 2, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 11, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 0, pred_y : 9, Real: 7, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 15, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 8, Predicted: 15
#  pred_x: 6, pred_y : 8, Real: 9, Predicted: 14
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 17, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 0, Real: 11, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 8, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 0, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 10, Predicted: 12
#  pred_x: 0, pred_y : 9, Real: 1, Predicted: 9
#  pred_x: 0, pred_y : 9, Real: 2, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 3, pred_y : 6, Real: 1, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 14, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 0, pred_y : 9, Real: 1, Predicted: 9
#  pred_x: 0, pred_y : 9, Real: 7, Predicted: 9
#  pred_x: 9, pred_y : 0, Real: 9, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 8, pred_y : 6, Real: 1, Predicted: 14
#  pred_x: 9, pred_y : 9, Real: 5, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 0, Real: 7, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 12, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 15, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 15, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 10, Predicted: 1
#  pred_x: 9, pred_y : 0, Real: 7, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 5, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 0, Real: 4, Predicted: 6
#  pred_x: 9, pred_y : 6, Real: 15, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 3, pred_y : 6, Real: 15, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 16, Predicted: 15
#  pred_x: 6, pred_y : 0, Real: 7, Predicted: 6
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 0, pred_y : 0, Real: 4, Predicted: 0
#  pred_x: 6, pred_y : 6, Real: 2, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 9, pred_y : 0, Real: 2, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 0, pred_y : 6, Real: 7, Predicted: 6
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 0, pred_y : 0, Real: 11, Predicted: 0
#  pred_x: 6, pred_y : 9, Real: 4, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 6, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 6, Predicted: 1
#  pred_x: 6, pred_y : 0, Real: 8, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 0, Real: 9, Predicted: 6
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 0, pred_y : 6, Real: 5, Predicted: 6
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 14, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 15, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 0, Real: 1, Predicted: 6
#  pred_x: 9, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 15, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 0, Real: 7, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 17, Predicted: 1
#  pred_x: 6, pred_y : 0, Real: 1, Predicted: 6
#  pred_x: 9, pred_y : 0, Real: 6, Predicted: 9
#  pred_x: 0, pred_y : 3, Real: 13, Predicted: 3
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 4, Predicted: 15
#  pred_x: 9, pred_y : 0, Real: 2, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 8, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 0, pred_y : 9, Real: 2, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 0, pred_y : 9, Real: 5, Predicted: 9
#  pred_x: 9, pred_y : 0, Real: 1, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 6, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 10, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 4, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 11, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 0, pred_y : 9, Real: 12, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 0, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 11, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 4, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 10, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 13, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 3, Real: 15, Predicted: 9
#  pred_x: 0, pred_y : 9, Real: 11, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 8, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 15, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 0, pred_y : 9, Real: 2, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 0, Real: 5, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 16, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 17, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 11, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 12, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 6, pred_y : 3, Real: 17, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 14, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 10, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 10, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 14, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 11, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 0, Real: 5, Predicted: 6
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 3, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 17, Predicted: 15
#  pred_x: 0, pred_y : 6, Real: 5, Predicted: 6
#  pred_x: 9, pred_y : 6, Real: 17, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 16, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 2, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 0, Real: 2, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 0, pred_y : 9, Real: 4, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 0, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 0, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 11, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 0, pred_y : 9, Real: 9, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 5, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 5, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 0, Real: 11, Predicted: 6
#  pred_x: 0, pred_y : 6, Real: 7, Predicted: 6
#  pred_x: 0, pred_y : 9, Real: 8, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 10, Predicted: 12
#  pred_x: 0, pred_y : 6, Real: 13, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 10, Predicted: 15
#  pred_x: 3, pred_y : 6, Real: 12, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 5, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 3, Real: 11, Predicted: 9
#  pred_x: 0, pred_y : 6, Real: 6, Predicted: 6
#  pred_x: 9, pred_y : 6, Real: 13, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 0, Real: 11, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 9, pred_y : 0, Real: 7, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 15, Predicted: 15
#  pred_x: 9, pred_y : 0, Real: 12, Predicted: 9
#  pred_x: 0, pred_y : 6, Real: 5, Predicted: 6
#  pred_x: 6, pred_y : 9, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 6, Predicted: 1
#  pred_x: 9, pred_y : 0, Real: 5, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 4, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 3, pred_y : 9, Real: 15, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 10, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 0, Real: 9, Predicted: 9
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 6, pred_y : 0, Real: 5, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 9, pred_y : 0, Real: 9, Predicted: 9
#  pred_x: 0, pred_y : 9, Real: 9, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 8, Predicted: 15
#  pred_x: 0, pred_y : 9, Real: 7, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 13, Predicted: 15
#  pred_x: 6, pred_y : 3, Real: 5, Predicted: 9
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 3, Real: 5, Predicted: 9
#  pred_x: 3, pred_y : 6, Real: 1, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 15, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 11, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 10, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 11, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 9, pred_y : 6, Real: 13, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 3, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 0, pred_y : 9, Real: 10, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 6, Predicted: 15
#  pred_x: 0, pred_y : 9, Real: 1, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 2, Predicted: 1
#  pred_x: 6, pred_y : 0, Real: 6, Predicted: 6
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 0, pred_y : 9, Real: 6, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 8, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 17, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 15, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 9, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 3, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 3, pred_y : 9, Real: 13, Predicted: 1
#  pred_x: 9, pred_y : 0, Real: 8, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 0, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 0, Real: 10, Predicted: 6
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 14, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 9, Real: 15, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 9, pred_y : 9, Real: 15, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 14, Predicted: 15
#  pred_x: 6, pred_y : 0, Real: 6, Predicted: 6
#  pred_x: 6, pred_y : 9, Real: 1, Predicted: 15
#  pred_x: 9, pred_y : 6, Real: 10, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 9, Predicted: 15
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 16, Predicted: 12
#  pred_x: 9, pred_y : 3, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 15, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 15, Predicted: 15
#  pred_x: 6, pred_y : 0, Real: 3, Predicted: 6
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 15, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 17, Predicted: 1
#  pred_x: 9, pred_y : 6, Real: 11, Predicted: 15
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
# Epoch 0, train_loss: 0.9898, train_accuracy: 0.0928, test_loss: 0.9844, test_accuracy: 0.0858
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 9, Real: 12, Predicted: 15
#  pred_x: 3, pred_y : 3, Real: 15, Predicted: 1
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 3, pred_y : 3, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 3, Real: 1, Predicted: 9
#  pred_x: 9, pred_y : 9, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 7, Predicted: 1
#  pred_x: 3, pred_y : 3, Real: 9, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 1, Predicted: 1
#  pred_x: 6, pred_y : 3, Real: 12, Predicted: 9
#  pred_x: 6, pred_y : 3, Real: 1, Predicted: 9
#  pred_x: 9, pred_y : 6, Real: 7, Predicted: 15
#  pred_x: 6, pred_y : 9, Real: 7, Predicted: 15
#  pred_x: 3, pred_y : 3, Real: 17, Predicted: 1
#  pred_x: 3, pred_y : 3, Real: 1, Predicted: 1
#  pred_x: 3, pred_y : 3, Real: 8, Predicted: 1
#  pred_x: 9, pred_y : 9, Real: 8, Predicted: 1
#  pred_x: 9, pred_y : 3, Real: 5, Predicted: 1
#  pred_x: 3, pred_y : 9, Real: 3, Predicted: 1
#  pred_x: 9, pred_y : 3, Real: 5, Predicted: 1
# ...
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 14, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 4, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 6, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 12, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 0, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 6, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 6, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 12, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 4, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 12, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 14, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 12, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 0, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 12, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 2, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 16, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 4, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 12, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 2, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 14, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 4, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 14, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 10, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 12, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 2, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 6, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 14, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 4, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 10, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 6, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 12, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 10, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 10, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 6, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 4, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 4, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 16, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 10, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 6, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 12, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 4, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 2, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 6, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 4, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 13, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 10, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 8, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 11, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 1, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 15, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 6, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 9, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 3, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 17, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 5, Predicted: 12
#  pred_x: 6, pred_y : 6, Real: 7, Predicted: 12
# Epoch 29, train_loss: 0.7581, train_accuracy: 0.0309, test_loss: 0.8450, test_accuracy: 0.0298

# %%
plt.figure()
plt.plot(range(len(history['train_accuracy'])), history['train_accuracy'], label='Train Accuracy')
plt.plot(range(len(history['test_accuracy'])), history['test_accuracy'], label='Test Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Model Accuracy over Epochs")
plt.grid(True)
plt.legend()
plt.show()

# Plot Loss
plt.figure()
plt.plot(range(len(history['train_loss'])), history['train_loss'], label='Train Loss')
plt.plot(range(len(history['test_loss'])), history['test_loss'], label='Test Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Model Loss over Epochs")
plt.grid(True)
plt.legend()
plt.show()
